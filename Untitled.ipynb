# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/angelinakathleen'

# %%
data = pd.read_csv('/Users/angelinakathleen/downloads/survey.csv')
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data = data.drop(['Timestamp'], axis = 1)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'state', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
data["Gender"].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
male = ['male', 'Male', 'M', 'm', 'Male-ish', 'maile', 'Cis Male', 
        'Mal', 'Male (CIS)', 'Make','Male ', 'Man', 'msle', 'Mail', 'cis male', 
        'Malr', 'Cis Man']
female = ['Female', 'female', 'Cis Female', 'F', 'Woman', 'f', 'Femake', 'woman', 'Female ', 'cis-female/femme', 'Female (cis)', 'femail']
other = ['Trans-female', 'something kinda male?', 'queer/she/they', 'non-binary', 'Nah', 'All', 'Enby', 'fluid', 'Genderqueer', 'Androgyne', 
         'Agender', 'Guy (-ish) ^_^', 'male leaning androgynous', 'Trans woman', 'Neuter', 'Female (trans)', 'queer', 'ostensibly male, unsure what that really means']

# %%
data = data[(data['Gender'] != 'A little about you') & (data['Gender'] != 'p')]

# %%
data.head()
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL           NaN             No       Yes
# 1   44       M   United States    IN           NaN             No        No
# 2   32    Male          Canada   NaN           NaN             No        No
# 3   31    Male  United Kingdom   NaN           NaN            Yes       Yes
# 4   31    Male   United States    TX           NaN             No        No
#
#   work_interfere    no_employees remote_work  ...               leave  \
# 0          Often            6-25          No  ...       Somewhat easy
# 1         Rarely  More than 1000          No  ...          Don't know
# 2         Rarely            6-25          No  ...  Somewhat difficult
# 3          Often          26-100          No  ...  Somewhat difficult
# 4          Never         100-500         Yes  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
data.replace(to_replace = male, value = 'male', inplace = True)
data.replace(to_replace = female, value = 'female', inplace = True)
data.replace(to_replace = other, value = 'other', inplace = True)

# %%
data.head()
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  female   United States    IL           NaN             No       Yes
# 1   44    male   United States    IN           NaN             No        No
# 2   32    male          Canada   NaN           NaN             No        No
# 3   31    male  United Kingdom   NaN           NaN            Yes       Yes
# 4   31    male   United States    TX           NaN             No        No
#
#   work_interfere    no_employees remote_work  ...               leave  \
# 0          Often            6-25          No  ...       Somewhat easy
# 1         Rarely  More than 1000          No  ...          Don't know
# 2         Rarely            6-25          No  ...  Somewhat difficult
# 3          Often          26-100          No  ...  Somewhat difficult
# 4          Never         100-500         Yes  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
data = data.dropna()
data
# Out:
#       Age  Gender        Country state self_employed family_history treatment  \
# 24     33    male  United States    CA            No            Yes       Yes
# 25     35    male  United States    TN            No            Yes       Yes
# 33     42    male  United States    WA            No            Yes       Yes
# 45     38  female  United States    TX            No            Yes       Yes
# 49     30    male  United States    IL            No            Yes       Yes
# ...   ...     ...            ...   ...           ...            ...       ...
# 1186   56  female  United States    OR           Yes             No        No
# 1190   44    male  United States    OH            No            Yes       Yes
# 1219   38    male  United States    TX            No             No       Yes
# 1221   46    male  United States    MD            No            Yes       Yes
# 1249   30    male  United States    CA            No            Yes       Yes
#
# ...

# %%
data['family_history'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['family_history'] = data['family_history'].map({'Yes':1,'No':0})
data
# Out:
#       Age  Gender        Country state self_employed  family_history  \
# 24     33    male  United States    CA            No               1
# 25     35    male  United States    TN            No               1
# 33     42    male  United States    WA            No               1
# 45     38  female  United States    TX            No               1
# 49     30    male  United States    IL            No               1
# ...   ...     ...            ...   ...           ...             ...
# 1186   56  female  United States    OR           Yes               0
# 1190   44    male  United States    OH            No               1
# 1219   38    male  United States    TX            No               0
# 1221   46    male  United States    MD            No               1
# 1249   30    male  United States    CA            No               1
#
#      treatment work_interfere    no_employees remote_work  ...          leave  \
# ...

# %%
data['treatment'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['treatment'] = data['treatment'].map({'Yes':1,'No':0})

# %%
data['work_interfere'].unique()
# Out:
# array(['Rarely', 'Sometimes', 'Often', 'Never'], dtype=object)

# %%
data['phys_health_interview'].unique()
# Out:
# array(['Yes', 'No', 'Maybe'], dtype=object)

# %%
data['phys_health_interview'] = data['phys_health_interview'].map({'Yes':1,'No':0, 'Maybe': 2})
data.head()
# Out:
#     Age  Gender        Country state self_employed  family_history  treatment  \
# 24   33    male  United States    CA            No               1          1
# 25   35    male  United States    TN            No               1          1
# 33   42    male  United States    WA            No               1          1
# 45   38  female  United States    TX            No               1          1
# 49   30    male  United States    IL            No               1          1
#
#    work_interfere    no_employees remote_work  ...          leave  \
# 24         Rarely          26-100          No  ...     Don't know
# 25      Sometimes  More than 1000          No  ...      Very easy
# 33      Sometimes          26-100         Yes  ...      Very easy
# 45      Sometimes          26-100          No  ...  Somewhat easy
# 49         Rarely          26-100          No  ...     Don't know
#
#    mental_health_consequence phys_health_consequence     coworkers  \
# ...

# %%
data.drop(['Country', 'state', 'comments'], axis = 1, inplace = True)
data.head()
# Out:
#     Age  Gender self_employed  family_history  treatment work_interfere  \
# 24   33    male            No               1          1         Rarely
# 25   35    male            No               1          1      Sometimes
# 33   42    male            No               1          1      Sometimes
# 45   38  female            No               1          1      Sometimes
# 49   30    male            No               1          1         Rarely
#
#       no_employees remote_work tech_company benefits  ...   anonymity  \
# 24          26-100          No          Yes      Yes  ...         Yes
# 25  More than 1000          No           No      Yes  ...          No
# 33          26-100         Yes          Yes      Yes  ...         Yes
# 45          26-100          No          Yes      Yes  ...         Yes
# 49          26-100          No          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['phys_health_interview'].unique()
# Out:
# array([1, 0, 2])

# %%
data['Gender'] = data['Gender'].map({'male':1,'female':0, 'other': 2})
data.head()
# Out:
#     Age  Gender self_employed  family_history  treatment work_interfere  \
# 24   33       1            No               1          1         Rarely
# 25   35       1            No               1          1      Sometimes
# 33   42       1            No               1          1      Sometimes
# 45   38       0            No               1          1      Sometimes
# 49   30       1            No               1          1         Rarely
#
#       no_employees remote_work tech_company benefits  ...   anonymity  \
# 24          26-100          No          Yes      Yes  ...         Yes
# 25  More than 1000          No           No      Yes  ...          No
# 33          26-100         Yes          Yes      Yes  ...         Yes
# 45          26-100          No          Yes      Yes  ...         Yes
# 49          26-100          No          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['self_employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['self_employed'] = data['self_employed'].map({'Yes':1,'No':0})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment work_interfere  \
# 24   33       1              0               1          1         Rarely
# 25   35       1              0               1          1      Sometimes
# 33   42       1              0               1          1      Sometimes
# 45   38       0              0               1          1      Sometimes
# 49   30       1              0               1          1         Rarely
#
#       no_employees remote_work tech_company benefits  ...   anonymity  \
# 24          26-100          No          Yes      Yes  ...         Yes
# 25  More than 1000          No           No      Yes  ...          No
# 33          26-100         Yes          Yes      Yes  ...         Yes
# 45          26-100          No          Yes      Yes  ...         Yes
# 49          26-100          No          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['work_interfere'].unique()
# Out:
# array(['Rarely', 'Sometimes', 'Often', 'Never'], dtype=object)

# %%
data['work_interfere'] = data['work_interfere'].map({'Never':0,'Rarely':1, 'Sometimes': 2, 'Often':3})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#       no_employees remote_work tech_company benefits  ...   anonymity  \
# 24          26-100          No          Yes      Yes  ...         Yes
# 25  More than 1000          No           No      Yes  ...          No
# 33          26-100         Yes          Yes      Yes  ...         Yes
# 45          26-100          No          Yes      Yes  ...         Yes
# 49          26-100          No          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['no_employees'].unique()
# Out:
# array(['26-100', 'More than 1000', '1-5', '6-25', '500-1000', '100-500'],
#       dtype=object)

# %%
data['no_employees'] = data['no_employees'].map({'1-5': 2,'6-25':9, '26-100':37,'100-500':200, '500-1000':250, 'More than 1000':2000})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees remote_work tech_company benefits  ...   anonymity  \
# 24            37          No          Yes      Yes  ...         Yes
# 25          2000          No           No      Yes  ...          No
# 33            37         Yes          Yes      Yes  ...         Yes
# 45            37          No          Yes      Yes  ...         Yes
# 49            37          No          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['remote_work'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['remote_work'] = data['remote_work'].map({'Yes':1,'No':0})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work tech_company benefits  ...   anonymity  \
# 24            37            0          Yes      Yes  ...         Yes
# 25          2000            0           No      Yes  ...          No
# 33            37            1          Yes      Yes  ...         Yes
# 45            37            0          Yes      Yes  ...         Yes
# 49            37            0          Yes      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['tech_company'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['tech_company'] = data['tech_company'].map({'Yes':1,'No':0})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company benefits  ...   anonymity  \
# 24            37            0             1      Yes  ...         Yes
# 25          2000            0             0      Yes  ...          No
# 33            37            1             1      Yes  ...         Yes
# 45            37            0             1      Yes  ...         Yes
# 49            37            0             1      Yes  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['benefits'].unique()
# Out:
# array(['Yes', "Don't know", 'No'], dtype=object)

# %%
data['benefits'] = data['benefits'].map({'Yes':1,'No':0, 'Don\'t know': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...   anonymity  \
# 24            37            0             1         1  ...         Yes
# 25          2000            0             0         1  ...          No
# 33            37            1             1         1  ...         Yes
# 45            37            0             1         1  ...         Yes
# 49            37            0             1         1  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['care_options'].unique()
# Out:
# array(['Not sure', 'Yes', 'No'], dtype=object)

# %%
data['care_options'] = data['care_options'].map({'Yes':1,'No':0, 'Not sure': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...   anonymity  \
# 24            37            0             1         1  ...         Yes
# 25          2000            0             0         1  ...          No
# 33            37            1             1         1  ...         Yes
# 45            37            0             1         1  ...         Yes
# 49            37            0             1         1  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['wellness_program'].unique()
# Out:
# array(["Don't know", 'No', 'Yes'], dtype=object)

# %%
data['wellness_program'] = data['wellness_program'].map({'Yes':1,'No':0, 'Don\'t know': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...   anonymity  \
# 24            37            0             1         1  ...         Yes
# 25          2000            0             0         1  ...          No
# 33            37            1             1         1  ...         Yes
# 45            37            0             1         1  ...         Yes
# 49            37            0             1         1  ...  Don't know
#
#             leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['seek_help'].unique()
# Out:
# array(['Yes', "Don't know", 'No'], dtype=object)

# %%
data['seek_help'] = data['seek_help'].map({'Yes':1,'No':0, 'Don\'t know': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...   anonymity  \
# 24            37            0             1         1  ...         Yes
# 25          2000            0             0         1  ...          No
# 33            37            1             1         1  ...         Yes
# 45            37            0             1         1  ...         Yes
# 49            37            0             1         1  ...  Don't know
#
#             leave  mental_health_consequence phys_health_consequence  \
# ...

# %%
data['anonymity'].unique()
# Out:
# array(['Yes', 'No', "Don't know"], dtype=object)

# %%
data['anonymity'] = data['anonymity'].map({'Yes':1,'No':0, 'Don\'t know': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...  anonymity  \
# 24            37            0             1         1  ...          1
# 25          2000            0             0         1  ...          0
# 33            37            1             1         1  ...          1
# 45            37            0             1         1  ...          1
# 49            37            0             1         1  ...          2
#
#             leave  mental_health_consequence  phys_health_consequence  \
# ...

# %%
data['leave'].unique()
# Out:
# array(["Don't know", 'Very easy', 'Somewhat easy', 'Somewhat difficult',
#        'Very difficult'], dtype=object)

# %%
data['leave'] = data['leave'].map({'Very difficult':0,'Somewhat difficult':1, 'Somewhat easy':2, 'Very easy':3,'Don\'t know': 4})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...  anonymity  leave  \
# 24            37            0             1         1  ...          1      4
# 25          2000            0             0         1  ...          0      3
# 33            37            1             1         1  ...          1      3
# 45            37            0             1         1  ...          1      2
# 49            37            0             1         1  ...          2      4
#
# ...

# %%
data['mental_health_consequence'].unique()
# Out:
# array(['No', 'Yes', 'Maybe'], dtype=object)

# %%
data['mental_health_consequence'] = data['mental_health_consequence'].map({'Yes':1,'No':0, 'Maybe': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...  anonymity  leave  \
# 24            37            0             1         1  ...          1      4
# 25          2000            0             0         1  ...          0      3
# 33            37            1             1         1  ...          1      3
# 45            37            0             1         1  ...          1      2
# 49            37            0             1         1  ...          2      4
#
# ...

# %%
data['coworkers'].unique()
# Out:
# array(['Yes', 'Some of them', 'No'], dtype=object)

# %%
data['coworkers'] = data['coworkers'].map({'Yes':1,'No':0, 'Some of them': 2})
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...  anonymity  leave  \
# 24            37            0             1         1  ...          1      4
# 25          2000            0             0         1  ...          0      3
# 33            37            1             1         1  ...          1      3
# 45            37            0             1         1  ...          1      2
# 49            37            0             1         1  ...          2      4
#
# ...

# %%
data['supervisor'].unique()
# Out:
# array(['Yes', 'Some of them', 'No'], dtype=object)

# %%
data['supervisor'] = data['supervisor'].map({'Yes':1,'No':0, 'Some of them': 2})

# %%
data['mental_health_interview'].unique()
# Out:
# array(['No', 'Maybe', 'Yes'], dtype=object)

# %%
data['mental_health_interview'] = data['mental_health_interview'].map({'Yes':1,'No':0, 'Maybe': 2})

# %%
data['mental_vs_physical'].unique()
# Out:
# array(["Don't know", 'No', 'Yes'], dtype=object)

# %%
data['mental_vs_physical'] = data['mental_vs_physical'].map({'Yes':1,'No':0, 'Don\'t know': 2})

# %%
data['obs_consequence'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['phys_health_consequence'].unique()
# Out:
# array(['No', 'Maybe', 'Yes'], dtype=object)

# %%
data['phys_health_consequence'] = data['phys_health_consequence'].map({'Yes':1,'No':0, 'Maybe': 2})

# %%
data['obs_consequence'] = data['obs_consequence'].map({'Yes':1,'No':0})

# %%
data.head()
# Out:
#     Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 24   33       1              0               1          1               1
# 25   35       1              0               1          1               2
# 33   42       1              0               1          1               2
# 45   38       0              0               1          1               2
# 49   30       1              0               1          1               1
#
#     no_employees  remote_work  tech_company  benefits  ...  anonymity  leave  \
# 24            37            0             1         1  ...          1      4
# 25          2000            0             0         1  ...          0      3
# 33            37            1             1         1  ...          1      3
# 45            37            0             1         1  ...          1      2
# 49            37            0             1         1  ...          2      4
#
# ...

# %%
plt.subplots(figsize=(20, 10))
sns.heatmap(data.corr(), cbar = True, annot=True)
# Out:
# <AxesSubplot:>

# %%
renew = data.drop(['self_employed', 'benefits',
       'no_employees', 'remote_work', 'tech_company',
       'care_options', 'wellness_program', 'seek_help',
       'anonymity',  'mental_health_consequence',
       'phys_health_consequence', 'coworkers', 'supervisor',
       'mental_health_interview', 'phys_health_interview',
       'mental_vs_physical', 'obs_consequence'], axis = 1)
renew.head()
# Out:
#     Age  Gender  family_history  treatment  work_interfere  leave
# 24   33       1               1          1               1      4
# 25   35       1               1          1               2      3
# 33   42       1               1          1               2      3
# 45   38       0               1          1               2      2
# 49   30       1               1          1               1      4

# %%
from sklearn.model_selection import train_test_split

X = renew.drop(['treatment'], axis = 1)
y = renew['treatment']
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=1/4,random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import f1_score

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
pred = model.predict(x_test)

# %%
acc = accuracy_score(y_test, pred)
confusion_matrix_test = metrics.confusion_matrix(y_test, pred)
recall = metrics.recall_score(y_test, pred)
precision = metrics.precision_score(y_test, pred)
mean_squared_error = metrics.mean_squared_error(y_test, pred)
score = model.score(x_test, y_test)
f1 = f1_score(y_test, pred)

# %%
print('Accuracy:', acc)
print('confusion_matrix_test:', confusion_matrix_test)
print('recall score:', recall)
print('precision:', precision)
print('mean_squared_error:', mean_squared_error)
print('score:', score)
print('f1 score:', f1)
# Out:
# Accuracy: 0.8571428571428571
# confusion_matrix_test: [[ 2  1]
#  [ 2 16]]
# recall score: 0.8888888888888888
# precision: 0.9411764705882353
# mean_squared_error: 0.14285714285714285
# score: 0.8571428571428571
# f1 score: 0.9142857142857143

# %%
from sklearn.ensemble import RandomForestClassifier

model_forest = RandomForestClassifier()
model_forest.fit(x_train, y_train)
preds = model_forest.predict(x_test)

# %%
acc1 = accuracy_score(y_test, preds)
confusion_matrix_test1 = metrics.confusion_matrix(y_test, preds)
recall1 = metrics.recall_score(y_test, preds)
precision1 = metrics.precision_score(y_test, preds)
mean_squared_error1 = metrics.mean_squared_error(y_test, preds)
score1 = model.score(x_test, y_test)
f1_1 = f1_score(y_test, preds)

# %%
print('Accuracy:', acc1)
print('confusion_matrix_test:', confusion_matrix_test1)
print('recall score:', recall1)
print('precision:', precision1)
print('mean_squared_error:', mean_squared_error1)
print('score:', score1)
print('f1 score:', f1_1)
# Out:
# Accuracy: 0.9047619047619048
# confusion_matrix_test: [[ 2  1]
#  [ 1 17]]
# recall score: 0.9444444444444444
# precision: 0.9444444444444444
# mean_squared_error: 0.09523809523809523
# score: 0.8571428571428571
# f1 score: 0.9444444444444444

# %%
# Out:
# 0.6190476190476191

# %%
# Out:
# 0.7333333333333334
